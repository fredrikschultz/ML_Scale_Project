# %% [markdown]
# # INIT PART #
# This part is just for connecting to hopsworks and downloading the dependicies needed.
#
# For the connecting to hopsworks we use the config file from Lab1 - somewhat moderized since we only need Hopsworks and not logging into Aqin. The config file uses our .env file that holds our respective hopsworks key.

# %%
import sys
from pathlib import Path
import os

root_dir = Path.cwd().parent   # ← one directory up
root_dir = str(root_dir)
print("Local environment")

# Add the root directory to the `PYTHONPATH` to use the `recsys` Python module from the notebook.
if root_dir not in sys.path:
    sys.path.append(root_dir)
print(f"Added the following directory to the PYTHONPATH: {root_dir}")
    
# Set the environment variables from the file <root_dir>/.env
import config
if os.path.exists(f"{root_dir}/.env"):
    settings = config.HopsworksSettings(_env_file=f"{root_dir}/.env")
# Out:
# Local environment
# Added the following directory to the PYTHONPATH: /Users/annastegaras/Desktop/ID2223/project/ML_Scale_Project
# HopsworksSettings initialized!

# %%
import hopsworks
# Check if HOPSWORKS_API_KEY env variable is set or if it is set in ~/.env
if settings.HOPSWORKS_API_KEY is not None:
    api_key = settings.HOPSWORKS_API_KEY.get_secret_value()
    os.environ['HOPSWORKS_API_KEY'] = api_key
project = hopsworks.login()
fs = project.get_feature_store()
# Out:
# 2026-01-06 17:26:07,745 INFO: Initializing external client
# 2026-01-06 17:26:07,745 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2026-01-06 17:26:09,440 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1286325

# %%
from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.metrics import mean_squared_error, r2_score
import hopsworks

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # CREATING THE FEATURE VIEW #
# The following part loads our three feature groups and the joins them in the feature view "stockholm_merged_fv", where total-landings will be the target label. All groups include date which will be used when joining so each column in each row correspond to the intended date.

# %%
# Retrieve feature groups
flight_arlanda_fg = fs.get_feature_group(
    name='flight_data_arlanda',
    version=1,
)
weather_data_fg = fs.get_feature_group(
    name='weather_flight',
    version=1,
)

google_trends_fg = fs.get_feature_group(
    name='google_trends_daily',
    version=1,
)

# %%
# Select features for training data.
selected_features_naive = (
    flight_arlanda_fg
        .select(['date','total_landings'])
        .join(weather_data_fg.select_features(), on=['city'])
        .join(google_trends_fg.select_features(), on=['city'])
)


feature_view = fs.get_or_create_feature_view(
    name='stockholm_as_label_fv',
    description="Combining weather, flights and other queryes to predict searches on Stockholm",
    version=1,
    labels=['stockholm'],
    query=selected_features_naive,
)
# Out:
# 2026-01-06 17:26:35,896 INFO: Using ['nights_per_day'] from feature group `hotel_data` as features for the query. To include primary key and event time use `select_all`.
# 2026-01-06 17:26:35,898 INFO: Using ['vikings', 'fika', 'stockholm', 'ikea', 'abba', 'vikings_7d_avg', 'fika_7d_avg', 'stockholm_7d_avg', 'ikea_7d_avg', 'abba_7d_avg'] from feature group `google_trends_daily` as features for the query. To include primary key and event time use `select_all`.
# Feature view created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1286325/fs/1265794/fv/hotel_nights_fv/version/1

# %% [markdown]
# # RETRIEVING THE TRAINING DATA IN "RAW" FORMAT #
# In this section we use train_test_split() from Hopsworks to split the data, and then we do a sanity check with just wrighting X_train to see that the data we have retrived is correct.

# %%
start_date_test_data = "2024-12-30"
# Convert string to datetime object

# %%
X_train, X_test, y_train, y_test = feature_view.train_test_split(
    test_start=start_date_test_data,
    test_end = "2025-05-11"
)
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (2.45s)
# 2026-01-06 17:33:25,417 INFO: Provenance cached data - overwriting last accessed/created training dataset from 1 to 2.

# %%
X_train
# Out:
#                            date  total_landings  vikings  fika  stockholm  \
# 0     2020-01-07 00:00:00+00:00           268.0      3.0   1.0       95.0
# 1     2020-01-08 00:00:00+00:00           276.0      3.0   1.0       89.0
# 2     2020-01-09 00:00:00+00:00           274.0      3.0   1.0       88.0
# 3     2020-01-10 00:00:00+00:00           143.0      3.0   1.0       83.0
# 4     2020-01-11 00:00:00+00:00           232.0      4.0   1.0       83.0
# ...                         ...             ...      ...   ...        ...
# 2043  2020-01-02 00:00:00+00:00           234.0      NaN   NaN        NaN
# 2044  2020-01-03 00:00:00+00:00           166.0      NaN   NaN        NaN
# 2045  2020-01-04 00:00:00+00:00           241.0      NaN   NaN        NaN
# 2046  2020-01-05 00:00:00+00:00           272.0      NaN   NaN        NaN
# 2047  2020-01-06 00:00:00+00:00           272.0      NaN   NaN        NaN
#
#       ikea  abba  vikings_7d_avg  fika_7d_avg  stockholm_7d_avg  ikea_7d_avg  \
# 0     48.0   1.0        2.857143          1.0         84.714286    63.857143
# 1     45.0   1.0        3.142857          1.0         87.000000    65.142857
# 2     47.0   1.0        3.142857          1.0         87.571429    62.714286
# 3     42.0   1.0        3.142857          1.0         87.000000    60.571429
# 4     62.0   1.0        3.142857          1.0         86.000000    58.142857
# ...    ...   ...             ...          ...               ...          ...
# 2043   NaN   NaN             NaN          NaN               NaN          NaN
# 2044   NaN   NaN             NaN          NaN               NaN          NaN
# 2045   NaN   NaN             NaN          NaN               NaN          NaN
# 2046   NaN   NaN             NaN          NaN               NaN          NaN
# 2047   NaN   NaN             NaN          NaN               NaN          NaN
#
#       abba_7d_avg
# 0        1.571429
# 1        1.142857
# 2        1.000000
# 3        1.000000
# 4        1.000000
# ...           ...
# 2043          NaN
# 2044          NaN
# 2045          NaN
# 2046          NaN
# 2047          NaN
#
# [1823 rows x 12 columns]

# %%
y_train
# Out:
#       nights_per_day
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 2043             NaN
# 2044             NaN
# 2045             NaN
# 2046             NaN
# 2047             NaN
#
# [1823 rows x 1 columns]

# %% [markdown]
# # DATA CLEANING AND FEATURE ENGINEERING
# In this section we will remove NAN values, we will also insert some new features based on the raw data. Because of this we only save raw data to feature groups and we do the feature engineering of adding for example lagging values and delta values for google trends here.

# %%
# 1. Checking the amount of rows containing NAN values
# The reason behind this is because our google prefill includes average values from the last 7 days 

nan_mask = X_train.isna().any(axis=1)
nan_mask.sum()   # how many bad rows
# Out:
# 367

# %%
# 2. We then remove these values from both X_train and y_train to assure correctness 

X_train = X_train.loc[~nan_mask].reset_index(drop=True)
y_train = y_train.loc[~nan_mask].reset_index(drop=True)

# %%
# 3. Sanity check to see that both X_train and y_train has the same amount of rows 
print(X_train.info())
print(y_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              1456 non-null   object
#  1   total_landings    1456 non-null   float32
#  2   vikings           1456 non-null   float64
#  3   fika              1456 non-null   float64
#  4   stockholm         1456 non-null   float64
#  5   ikea              1456 non-null   float64
#  6   abba              1456 non-null   float64
#  7   vikings_7d_avg    1456 non-null   float64
#  8   fika_7d_avg       1456 non-null   float64
#  9   stockholm_7d_avg  1456 non-null   float64
#  10  ikea_7d_avg       1456 non-null   float64
#  11  abba_7d_avg       1456 non-null   float64
# dtypes: float32(1), float64(10), object(1)
# memory usage: 130.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nights_per_day  1456 non-null   float32
# dtypes: float32(1)
# memory usage: 5.8 KB
# None

# %%
X_train
# Out:
#                            date  total_landings  vikings  fika  stockholm  \
# 0     2021-01-01 00:00:00+00:00           142.0      9.0   2.0       74.0
# 1     2021-01-02 00:00:00+00:00           194.0     10.0   2.0       76.0
# 2     2021-01-03 00:00:00+00:00           172.0      8.0   2.0       79.0
# 3     2021-01-04 00:00:00+00:00           136.0      6.0   2.0       89.0
# 4     2021-01-05 00:00:00+00:00           138.0      5.0   1.0       85.0
# ...                         ...             ...      ...   ...        ...
# 1451  2024-12-25 00:00:00+00:00           180.0      1.0   1.0       76.0
# 1452  2024-12-26 00:00:00+00:00           192.0      1.0   1.0       83.0
# 1453  2024-12-27 00:00:00+00:00           146.0      1.0   2.0       85.0
# 1454  2024-12-28 00:00:00+00:00           202.0      1.0   2.0       80.0
# 1455  2024-12-29 00:00:00+00:00           195.0      1.0   2.0       82.0
#
#        ikea  abba  vikings_7d_avg  fika_7d_avg  stockholm_7d_avg  ikea_7d_avg  \
# 0      77.0   2.0        4.000000     1.714286         78.000000    71.000000
# 1      91.0   1.0        5.000000     1.857143         77.571429    71.714286
# 2     100.0   1.0        6.000000     2.000000         76.714286    73.428571
# 3      73.0   0.0        6.857143     2.000000         76.428571    74.857143
# 4      75.0   1.0        7.428571     2.000000         77.000000    74.571429
# ...     ...   ...             ...          ...               ...          ...
# 1451   56.0   2.0        0.857143     2.285714         78.571429    40.000000
# 1452   61.0   1.0        0.857143     2.142857         77.571429    43.000000
# 1453   54.0   1.0        0.857143     2.000000         78.000000    46.857143
# 1454   63.0   1.0        0.857143     2.000000         78.857143    49.714286
# 1455   63.0   1.0        0.857143     1.857143         78.000000    51.285714
#
#       abba_7d_avg
# 0        1.571429
# 1        1.714286
# 2        1.714286
# 3        1.714286
# 4        1.571429
# ...           ...
# 1451     1.571429
# 1452     1.714286
# 1453     1.571429
# 1454     1.571429
# 1455     1.428571
#
# [1456 rows x 12 columns]

# %%
X_test
# Out:
#                            date  total_landings  vikings  fika  stockholm  \
# 1816  2024-12-30 00:00:00+00:00           123.0      1.0   2.0       86.0
# 1817  2024-12-31 00:00:00+00:00           150.0      1.0   2.0       77.0
# 1818  2025-01-01 00:00:00+00:00           213.0      1.0   1.0       88.0
# 1819  2025-01-02 00:00:00+00:00           209.0      1.0   2.0       88.0
# 1820  2025-01-03 00:00:00+00:00           159.0      1.0   1.0       88.0
# ...                         ...             ...      ...   ...        ...
# 2153  2025-11-25 00:00:00+00:00           243.0      0.0   1.0       57.0
# 2154  2025-11-26 00:00:00+00:00           269.0      0.0   1.0       59.0
# 2155  2025-11-27 00:00:00+00:00           269.0      1.0   1.0       60.0
# 2156  2025-11-28 00:00:00+00:00           150.0      1.0   2.0       68.0
# 2157  2025-11-29 00:00:00+00:00           253.0      1.0   2.0       97.0
#
#       ikea  abba  vikings_7d_avg  fika_7d_avg  stockholm_7d_avg  ikea_7d_avg  \
# 1816  54.0   1.0        0.857143     1.714286         78.714286    52.285714
# 1817  33.0   5.0        0.857143     1.571429         79.857143    54.857143
# 1818  51.0   2.0        1.000000     1.714286         81.285714    54.857143
# 1819  59.0   1.0        1.000000     1.714286         83.000000    54.142857
# 1820  53.0   1.0        1.000000     1.857143         83.714286    53.857143
# ...    ...   ...             ...          ...               ...          ...
# 2153  28.0   1.0        0.285714     1.285714         63.857143    32.428571
# 2154  29.0   1.0        0.285714     1.285714         61.285714    32.000000
# 2155  28.0   1.0        0.142857     1.285714         60.000000    32.428571
# 2156  29.0   1.0        0.285714     1.285714         60.142857    32.714286
# 2157  58.0   1.0        0.428571     1.428571         61.285714    33.000000
#
#       abba_7d_avg
# 1816     1.285714
# 1817     1.142857
# 1818     1.714286
# 1819     1.714286
# 1820     1.714286
# ...           ...
# 2153     1.428571
# 2154     1.428571
# 2155     1.428571
# 2156     1.428571
# 2157     1.428571
#
# [335 rows x 12 columns]

# %%
X_features = X_train.drop(columns=['date','stockholm_7d_avg'])
X_test_features = X_test.drop(columns=['date','stockholm_7d_avg'])

# %%
"""X_train['lag_1'] = y_train['total_landings'].shift(1)
X_train['lag_7'] = y_train['total_landings'].shift(7)
X_train['rolling_7'] = y_train['total_landings'].shift(1).rolling(7).mean()

#X_train.dropna(inplace=True)
X_train"""
# Out:
# "X_train['lag_1'] = y_train['total_landings'].shift(1)\nX_train['lag_7'] = y_train['total_landings'].shift(7)\nX_train['rolling_7'] = y_train['total_landings'].shift(1).rolling(7).mean()\n\n#X_train.dropna(inplace=True)\nX_train"

# %%
"""X_test = add_operational_features(X_test)

X_test['lag_1'] = y_test['total_landings'].shift(1)
X_test['lag_7'] = y_test['total_landings'].shift(7)
X_test['rolling_7'] = y_test['total_landings'].shift(1).rolling(7).mean()

X_test.dropna(inplace=True)
X_test"""
# Out:
# "X_test = add_operational_features(X_test)\n\nX_test['lag_1'] = y_test['total_landings'].shift(1)\nX_test['lag_7'] = y_test['total_landings'].shift(7)\nX_test['rolling_7'] = y_test['total_landings'].shift(1).rolling(7).mean()\n\nX_test.dropna(inplace=True)\nX_test"

# %% [markdown]
# # MODELING

# %%
# Creating an instance of the XGBoost Regressor
xgb_regressor = XGBRegressor()

# Fitting the XGBoost Regressor to the training data
xgb_regressor.fit(X_features, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Predicting target values on the test set
y_pred = xgb_regressor.predict(X_test_features)

# Calculating Mean Squared Error (MSE) using sklearn
mse = mean_squared_error(y_test.iloc[:,0], y_pred)
print("MSE:", mse)

# Calculating R squared using sklearn
r2 = r2_score(y_test.iloc[:,0], y_pred)
print("R squared:", r2)
# Out:
# MSE: 74049040.0
# R squared: 0.2125664193437069

# %%
df = y_test
df['predicted_query_stockholm'] = y_pred

# %%
df['date'] = X_test['date']
df = df.sort_values(by=['date'])
df.head(5)
# Out:
#       nights_per_day  predicted_nights_stockholm                       date
# 1816         35018.0                18191.234375  2024-12-30 00:00:00+00:00
# 1817         48126.0                44237.921875  2024-12-31 00:00:00+00:00
# 1818         29231.0                20444.382812  2025-01-01 00:00:00+00:00
# 1819         28968.0                20007.123047  2025-01-02 00:00:00+00:00
# 1820         30261.0                17678.263672  2025-01-03 00:00:00+00:00

# %%
# Creating a directory for the model artifacts if it doesn't exist
model_dir = "flight_weather_trends_model"
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
images_dir = model_dir + "/images"
if not os.path.exists(images_dir):
    os.mkdir(images_dir)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.ticker import MultipleLocator
import pandas as pd

def plot_landing_forecast(city: str,
                          df: pd.DataFrame,
                          file_path: str,
                          hindcast=False):

    fig, ax1 = plt.subplots(figsize=(12, 6))

    day = pd.to_datetime(df['date'])

    # ---- Main axis: landings ----
    ax1.plot(day, df['predicted_landings'],
             label='Predicted Landings',
             color='tab:blue', linewidth=2, marker='o')

    if hindcast:
        ax1.plot(day, df['stockholm'],
                 label='Actual Landings',
                 color='black', linewidth=2, marker='^')

    ax1.set_ylabel('Daily Landings')
    ax1.set_xlabel('Date')
    ax1.set_title(f"Daily Aircraft Landings Forecast – {city}")
    ax1.legend(loc='upper left')

    # ---- X-axis density control ----
    if len(df) > 12:
        ax1.xaxis.set_major_locator(MultipleLocator(len(df) // 10))

    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(file_path)
    return plt
    
plot_landing_forecast("Märsta", df, "flight_weather_model/images", hindcast=True)
# Out:
# <module 'matplotlib.pyplot' from '/Users/annastegaras/miniconda3/envs/aq/lib/python3.11/site-packages/matplotlib/pyplot.py'>

# %%
# Plotting feature importances using the plot_importance function from XGBoost
plot_importance(xgb_regressor)
feature_importance_path = images_dir + "/feature_importance.png"
plt.savefig(feature_importance_path)
plt.show()
