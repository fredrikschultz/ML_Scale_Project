# %%
import sys
from pathlib import Path
import os

root_dir = Path.cwd().parent   # ← one directory up
root_dir = str(root_dir)
print("Local environment")

# Add the root directory to the `PYTHONPATH` to use the `recsys` Python module from the notebook.
if root_dir not in sys.path:
    sys.path.append(root_dir)
print(f"Added the following directory to the PYTHONPATH: {root_dir}")
    
# Set the environment variables from the file <root_dir>/.env
import config
if os.path.exists(f"{root_dir}/.env"):
    settings = config.HopsworksSettings(_env_file=f"{root_dir}/.env")
# Out:
# Local environment
# Added the following directory to the PYTHONPATH: /Users/annastegaras/Desktop/ID2223/project/ML_Scale_Project
# HopsworksSettings initialized!

# %%
from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.metrics import mean_squared_error, r2_score
import hopsworks

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Some comments

# %%
# Check if HOPSWORKS_API_KEY env variable is set or if it is set in ~/.env
if settings.HOPSWORKS_API_KEY is not None:
    api_key = settings.HOPSWORKS_API_KEY.get_secret_value()
    os.environ['HOPSWORKS_API_KEY'] = api_key
project = hopsworks.login()
fs = project.get_feature_store()
# Out:
# 2026-01-05 19:21:08,284 INFO: Closing external client and cleaning up certificates.
# Connection closed.
# 2026-01-05 19:21:08,290 INFO: Initializing external client
# 2026-01-05 19:21:08,291 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2026-01-05 19:21:10,020 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1286325

# %%
# Retrieve feature groups
flight_arlanda_fg = fs.get_feature_group(
    name='flight_data_arlanda',
    version=1,
)
weather_data_fg = fs.get_feature_group(
    name='weather_flight',
    version=1,
)

# %%
# Select features for training data.
selected_features_naive = flight_arlanda_fg.select(['date','total_landings']).join(weather_data_fg.select_features(), on=['city'])

feature_view = fs.get_or_create_feature_view(
    name='stockholm_flights_weather_fv',
    description="Combining weather and flights to arlanda",
    version=1,
    labels=['total_landings'],
    query=selected_features_naive,
)
# Out:
# 2026-01-05 19:21:12,735 INFO: Using ['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant'] from feature group `weather_flight` as features for the query. To include primary key and event time use `select_all`.

# %%
start_date_test_data = "2024-12-30"
# Convert string to datetime object
# Out:
# 2024-12-30 00:00:00

# %%
X_train, X_test, y_train, y_test = feature_view.train_test_split(
    test_start=start_date_test_data,
    test_end = "2025-05-11"
)
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.78s)
# 2026-01-05 19:36:59,382 INFO: Provenance cached data - overwriting last accessed/created training dataset from 4 to 5.

# %%
def add_operational_features(df):
    df = df.copy()
    # Make sure date is datetime
    df['date'] = pd.to_datetime(df['date']).dt.normalize()
    
    # Month extracted from date
    df['month'] = df['date'].dt.month
    
    # Weekday
    df['dow'] = df['date'].dt.weekday
    df['is_weekend'] = (df['dow'] >= 5).astype(int)
    
    # Seasonal regimes (Nordic meteorological seasons)
    df['is_winter'] = df['month'].isin([12, 1, 2]).astype(int)
    df['is_spring'] = df['month'].isin([3, 4, 5]).astype(int)
    df['is_summer'] = df['month'].isin([6, 7, 8]).astype(int)
    df['is_autumn'] = df['month'].isin([9, 10, 11]).astype(int)
    
    # High traffic peak season (charter peak)
    df['is_peak_season'] = df['month'].isin([6, 7, 8]).astype(int)
    df['is_deep_winter'] = df['month'].isin([1, 2]).astype(int)
    return df

# %%
X_train = add_operational_features(X_train)

X_train['lag_1'] = y_train['total_landings'].shift(1)
X_train['lag_7'] = y_train['total_landings'].shift(7)
X_train['rolling_7'] = y_train['total_landings'].shift(1).rolling(7).mean()

X_train.dropna(inplace=True)
X_train
# Out:
#                           date  temperature_2m_mean  precipitation_sum  \
# 7    2020-01-07 00:00:00+00:00             5.306250                0.0
# 8    2020-01-08 00:00:00+00:00             6.743750                0.0
# 9    2020-01-09 00:00:00+00:00             1.327083                0.0
# 10   2020-01-10 00:00:00+00:00            -1.522917                0.0
# 11   2020-01-11 00:00:00+00:00            -0.035417                1.9
# ...                        ...                  ...                ...
# 1818 2024-12-25 00:00:00+00:00             5.558334                0.0
# 1819 2024-12-26 00:00:00+00:00             6.193750                0.0
# 1820 2024-12-27 00:00:00+00:00             4.210417                0.0
# 1821 2024-12-28 00:00:00+00:00             4.574999                0.0
# 1822 2024-12-29 00:00:00+00:00             6.056250                1.0
#
#       wind_speed_10m_max  wind_direction_10m_dominant  month  dow  is_weekend  \
# 7              24.336639                   219.694382      1    1           0
# 8              29.533169                   234.557602      1    2           0
# 9              21.995380                   251.377396      1    3           0
# 10             10.464797                    17.833914      1    4           0
# 11             30.563978                   220.088608      1    5           1
# ...                  ...                          ...    ...  ...         ...
# 1818           21.060770                   237.642151     12    2           0
# 1819           21.175835                   252.496140     12    3           0
# 1820           14.897651                   268.204193     12    4           0
# 1821           19.361507                   228.279053     12    5           1
# 1822           30.008217                   237.526184     12    6           1
#
#       is_winter  is_spring  is_summer  is_autumn  is_peak_season  \
# 7             1          0          0          0               0
# 8             1          0          0          0               0
# 9             1          0          0          0               0
# 10            1          0          0          0               0
# 11            1          0          0          0               0
# ...         ...        ...        ...        ...             ...
# 1818          1          0          0          0               0
# 1819          1          0          0          0               0
# 1820          1          0          0          0               0
# 1821          1          0          0          0               0
# 1822          1          0          0          0               0
#
#       is_deep_winter  lag_1  lag_7   rolling_7
# 7                  1  272.0  178.0  228.857143
# 8                  1  268.0  239.0  241.714286
# 9                  1  276.0  234.0  247.000000
# 10                 1  274.0  166.0  252.714286
# 11                 1  143.0  241.0  249.428571
# ...              ...    ...    ...         ...
# 1818               0  109.0  237.0  175.857143
# 1819               0  180.0  218.0  167.714286
# 1820               0  192.0  159.0  164.000000
# 1821               0  146.0  213.0  162.142857
# 1822               0  202.0  198.0  160.571429
#
# [1816 rows x 17 columns]

# %%
X_test = add_operational_features(X_test)

X_test['lag_1'] = y_test['total_landings'].shift(1)
X_test['lag_7'] = y_test['total_landings'].shift(7)
X_test['rolling_7'] = y_test['total_landings'].shift(1).rolling(7).mean()

X_test.dropna(inplace=True)
X_test
# Out:
#                           date  temperature_2m_mean  precipitation_sum  \
# 1830 2025-01-06 00:00:00+00:00            -3.145833                5.0
# 1831 2025-01-07 00:00:00+00:00             1.695833                4.8
# 1832 2025-01-08 00:00:00+00:00             0.241667                2.1
# 1833 2025-01-09 00:00:00+00:00            -3.927083                0.0
# 1834 2025-01-10 00:00:00+00:00            -1.510417                1.8
# ...                        ...                  ...                ...
# 1950 2025-05-06 00:00:00+00:00             5.995833                0.0
# 1951 2025-05-07 00:00:00+00:00             5.595833                0.6
# 1952 2025-05-08 00:00:00+00:00             6.429167                0.1
# 1953 2025-05-09 00:00:00+00:00             4.283334                3.9
# 1954 2025-05-10 00:00:00+00:00             6.208333                0.0
#
#       wind_speed_10m_max  wind_direction_10m_dominant  month  dow  is_weekend  \
# 1830           27.509394                   104.500664      1    0           0
# 1831           26.052162                   169.390625      1    1           0
# 1832           19.804090                   178.487045      1    2           0
# 1833           10.190289                   228.158844      1    3           0
# 1834           32.404499                     8.294682      1    4           0
# ...                  ...                          ...    ...  ...         ...
# 1950           24.640940                   352.452118      5    1           0
# 1951           14.489720                    13.370045      5    2           0
# 1952           15.391840                    42.370411      5    3           0
# 1953           14.073421                   144.422974      5    4           0
# 1954            9.179999                    76.399429      5    5           1
#
#       is_winter  is_spring  is_summer  is_autumn  is_peak_season  \
# 1830          1          0          0          0               0
# 1831          1          0          0          0               0
# 1832          1          0          0          0               0
# 1833          1          0          0          0               0
# 1834          1          0          0          0               0
# ...         ...        ...        ...        ...             ...
# 1950          0          1          0          0               0
# 1951          0          1          0          0               0
# 1952          0          1          0          0               0
# 1953          0          1          0          0               0
# 1954          0          1          0          0               0
#
#       is_deep_winter  lag_1  lag_7   rolling_7
# 1830               1  211.0  123.0  180.571429
# 1831               1  200.0  150.0  191.571429
# 1832               1  173.0  213.0  194.857143
# 1833               1  201.0  209.0  193.142857
# 1834               1  208.0  159.0  193.000000
# ...              ...    ...    ...         ...
# 1950               0  293.0  282.0  255.857143
# 1951               0  306.0  229.0  259.285714
# 1952               0  300.0  231.0  269.428571
# 1953               0  307.0  193.0  280.285714
# 1954               0  212.0  275.0  283.000000
#
# [125 rows x 17 columns]

# %%
X_features = X_train.drop(columns=['date'])
X_test_features = X_test.drop(columns=['date'])

# %%
y_train=y_train.iloc[7:].copy()
y_train
# Out:
#       total_landings
# 7              268.0
# 8              276.0
# 9              274.0
# 10             143.0
# 11             232.0
# ...              ...
# 1818           180.0
# 1819           192.0
# 1820           146.0
# 1821           202.0
# 1822           195.0
#
# [1816 rows x 1 columns]

# %%
y_test = y_test.iloc[7:].copy()

# %% [markdown]
# MODELING

# %%
# Creating an instance of the XGBoost Regressor
xgb_regressor = XGBRegressor()

# Fitting the XGBoost Regressor to the training data
xgb_regressor.fit(X_features, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Predicting target values on the test set
y_pred = xgb_regressor.predict(X_test_features)

# Calculating Mean Squared Error (MSE) using sklearn
mse = mean_squared_error(y_test.iloc[:,0], y_pred)
print("MSE:", mse)

# Calculating R squared using sklearn
r2 = r2_score(y_test.iloc[:,0], y_pred)
print("R squared:", r2)
# Out:
# MSE: 7749.264
# R squared: -2.628879309362869

# %%
df = y_test
df['predicted_landings'] = y_pred

# %%
df['date'] = X_test['date']
df = df.sort_values(by=['date'])
df.head(5)
# Out:
#       total_landings  predicted_landings                      date
# 1830           200.0          151.008026 2025-01-06 00:00:00+00:00
# 1831           173.0          162.803543 2025-01-07 00:00:00+00:00
# 1832           201.0          216.435989 2025-01-08 00:00:00+00:00
# 1833           208.0          226.874893 2025-01-09 00:00:00+00:00
# 1834           131.0          227.501266 2025-01-10 00:00:00+00:00

# %%
# Creating a directory for the model artifacts if it doesn't exist
model_dir = "flight_weather_model"
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
images_dir = model_dir + "/images"
if not os.path.exists(images_dir):
    os.mkdir(images_dir)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.ticker import MultipleLocator
import pandas as pd

def plot_landing_forecast(city: str,
                          df: pd.DataFrame,
                          file_path: str,
                          hindcast=False):

    fig, ax1 = plt.subplots(figsize=(12, 6))

    day = pd.to_datetime(df['date'])

    # ---- Main axis: landings ----
    ax1.plot(day, df['predicted_landings'],
             label='Predicted Landings',
             color='tab:blue', linewidth=2, marker='o')

    if hindcast:
        ax1.plot(day, df['total_landings'],
                 label='Actual Landings',
                 color='black', linewidth=2, marker='^')

    ax1.set_ylabel('Daily Landings')
    ax1.set_xlabel('Date')
    ax1.set_title(f"Daily Aircraft Landings Forecast – {city}")
    ax1.legend(loc='upper left')

    # ---- X-axis density control ----
    if len(df) > 12:
        ax1.xaxis.set_major_locator(MultipleLocator(len(df) // 10))

    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(file_path)
    return plt
    
plot_landing_forecast("Märsta", df, "flight_weather_model/images", hindcast=True)
# Out:
# <module 'matplotlib.pyplot' from '/Users/annastegaras/miniconda3/envs/aq/lib/python3.11/site-packages/matplotlib/pyplot.py'>

# %%
# Plotting feature importances using the plot_importance function from XGBoost
plot_importance(xgb_regressor)
feature_importance_path = images_dir + "/feature_importance.png"
plt.savefig(feature_importance_path)
plt.show()
